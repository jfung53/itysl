# %%
from bs4 import BeautifulSoup
import lxml
import os
import requests
import csv

# %%
url = "https://subslikescript.com/series/I_Think_You_Should_Leave_with_Tim_Robinson-10050772/season-1/episode-2-Thanks_for_Thinking_They_Are_Cool"
r = requests.get(url)

# %%
# get html content and pass into soup object
source = r.content
soup = BeautifulSoup(source, 'lxml')

# %%
soup.find_all('div', class_='full-script')
# Out:
# []
