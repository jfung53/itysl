# %% [markdown]
# Some of the transcripts from https://itysldb.com/ were missing words.
#
# I'll compare the transcripts with the ones scraped from [another website](https://subslikescript.com/series/I_Think_You_Should_Leave_with_Tim_Robinson-10050772).

# %%
import scrapy
from scrapy.selector import Selector
import requests

# %%
url = "https://subslikescript.com/series/I_Think_You_Should_Leave_with_Tim_Robinson-10050772/season-1/episode-2-Thanks_for_Thinking_They_Are_Cool"
response = requests.get(url)
sel = Selector(text=response.text)
response
# Out:
# <Response [403]>
